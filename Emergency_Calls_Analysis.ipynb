# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mchirico/911Calls/master/911.csv"
df = pd.read_csv(url)

df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1608596357.py in <cell line: 0>()
#       2
#       3 url = "https://raw.githubusercontent.com/mchirico/911Calls/master/911.csv"
# ----> 4 df = pd.read_csv(url)
#       5
#       6 df.head()
#
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mchirico/911Calls/master/911.csv"
df = pd.read_csv(url)

df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-4288184906.py in <cell line: 0>()
#       2
#       3 url = "https://raw.githubusercontent.com/mchirico/911Calls/master/911.csv"
# ----> 4 df = pd.read_csv(url)
#       5
#       6 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/911.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3159116158.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/content/911.csv')
#       4 df.head()
#
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mchirico/911Calls/master/911.csv"
df = pd.read_csv(url, encoding='latin1')

df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-60510110.py in <cell line: 0>()
#       2
#       3 url = "https://raw.githubusercontent.com/mchirico/911Calls/master/911.csv"
# ----> 4 df = pd.read_csv(url, encoding='latin1')
#       5
#       6 df.head()
#
# ...

# %%
import pandas as pd

url = "https://data.world/awram/911-calls-for-service/workspace/file?filename=911.csv"
df = pd.read_csv(url)

df.head()
# Out:
# Empty DataFrame
# ...

# %%
import pandas as pd

# Create emergency calls dataset
data = {
    'Reason': ['EMS', 'Fire', 'Traffic', 'EMS', 'Traffic', 'Fire', 'EMS', 'Traffic'],
    'Hour': [9, 14, 18, 22, 7, 16, 11, 20],
    'Day': ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday'],
    'Calls': [120, 80, 150, 90, 200, 70, 130, 160]
}

df = pd.DataFrame(data)
df
# Out:
#     Reason  Hour        Day  Calls
# 0      EMS     9     Monday    120
# 1     Fire    14    Tuesday     80
# 2  Traffic    18  Wednesday    150
# 3      EMS    22   Thursday     90
# 4  Traffic     7     Friday    200
# 5     Fire    16   Saturday     70
# 6      EMS    11     Sunday    130
# 7  Traffic    20     Monday    160

# %%
# Total calls
df['Calls'].sum()
# Out:
# np.int64(1000)

# %%
# Calls grouped by reason
df.groupby('Reason')['Calls'].sum()
# Out:
# Reason
# EMS        340
# Fire       150
# Traffic    510
# Name: Calls, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x='Reason', y='Calls', data=df)
plt.title("Emergency Calls by Reason")
plt.show()

# %%
sns.lineplot(x='Hour', y='Calls', data=df)
plt.title("Emergency Calls by Hour")
plt.show()

# %%
sns.barplot(x='Day', y='Calls', data=df)
plt.xticks(rotation=45)
plt.title("Emergency Calls by Day")
plt.show()
